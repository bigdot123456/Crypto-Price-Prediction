# %%
import requests      
from datetime import datetime
from bs4 import BeautifulSoup  
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet
import re, csv, string 
import gensim
import pandas as pd
from gensim import corpora, models
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import numpy as np


#------------------------------------------------HELPER FUNCTIONS---------------------------------------------------------
## Separates headlines out from 'all_data' variable so it can be written to separate columns in csv
def get_headline_list(filtered_data, index):
    headlines_list = []
    for row in filtered_data:
        headlines_list.append(row[index])
    return headlines_list

## Separate dates out from 'all_data' variable so it can be written to separate columns in csv
def get_date_list(filtered_data, index):
    date_list = []
    for row in filtered_data:
        date_list.append(row[index])
    return date_list

## Handle cleaning of one specific date format
def tokenize_date(s):
    pattern=r'[a-zA-Z{3}]+[.\s]+[\d{1,2}\,\s]+[\d{4}]+'                        
    tokens=nltk.regexp_tokenize(s, pattern)
    date = tokens
    return date


#--------------------------------------------------WEB SCRAPERS---------------------------------------------------------
def get_bloomberg_headlines():
    headlines=[]  # list variable to store headlines
    dates = []    # list variable to store dates
    raw_headlines = [] 
    page_number = 1
    page_url="https://www.bloomberg.com/search?query=bitcoin&sort=time:desc&endTime=2018-04-27T17:35:17.135Z&page="+str(page_number)
    # loop until page 80
    while page_url!="https://www.bloomberg.com/search?query=bitcoin&sort=time:desc&endTime=2018-04-27T17:35:17.135Z&page=80":     
        page_url="https://www.bloomberg.com/search?query=bitcoin&sort=time:desc&endTime=2018-04-27T17:35:17.135Z&page="+str(page_number)
        page = requests.get(page_url) 
        page_number += 1
        if page_number % 20 == 0:
            print('scraped %s of 80 pages' % page_number)
        if page.status_code!=200:  
            page_number = 80 #if page status code fails to equal 200, connection failed; set page_num to while loop condition
        else:                   
            soup = BeautifulSoup(page.content, 'html.parser')                        
            
#-----------scrape and clean all headlines and append to a list called headlines----------------------------------------------
            for header in soup.find_all('h1', class_ ='search-result-story__headline'):
                headline = header.get_text().lower()
                raw_headlines.append(headline)
                
#-----------scrape all dates and append to a list called dates---------------------------------------------------------------
            for date in soup.find_all('time', class_ = 'published-at'):
                date_published = date.get_text()
                date_published = date_published.lstrip()
                dates.append(date_published)
                 
#---join headlines list and dates list into a list of tuples called raw_data-----------------------------------------------------
    raw_data = zip(raw_headlines, dates)
    
    return raw_data

def marketwatch_parser():
    headlines=[]
    page_url= "https://www.marketwatch.com/search?q=bitcoin&m=Keyword&rpp=500&mp=806&bd=false&bdv=&rs=false"
    while page_url!=None:
        page = requests.get(page_url) 
        if page.status_code!=200:
             page_url=None
        else:
            all_data = []
            all_data_raw = []
            page_url = "https://www.marketwatch.com/search?q=bitcoin&m=Keyword&rpp=500&mp=806&bd=false&bdv=&rs=false"
            page = requests.get(page_url)
            soup = BeautifulSoup(page.content, "html.parser")
            divs = soup.find_all("div", class_ = "searchresult")
            titles_dictionary = []
            raw_headlines = []
            for idx, div in enumerate(divs):
                titles = div.select("a")
                if titles != []:
                    title = titles[0].get_text()
                    raw_headlines.append(title)
            divs_dates = soup.find_all("div", class_ = "deemphasized")
            dates_list = []
            for idx, div in enumerate(divs_dates):
                date = div.get_text().lower()
                date = str(tokenize_date(date)[0])
                date = datetime.strptime(date.replace("sept.","sep.").replace("july", "jul.").replace("june", "jun.").replace("may", "may.").replace("march", "mar.").replace("april", "apr."), '%b. %d, %Y')
                date = datetime.strftime(date,'%b %d, %Y')
                dates_list.append(date)
            raw_data = zip(raw_headlines, dates_list)
        page_url = None
    return raw_data

def get_wsj_headlines():
    f = open('wsj_data.txt', 'r',encoding='latin-1')
    lines = [line for line in f]  
    headline_info = []
    raw_headlines = []
    date_info = []
    left_side_info = []
    right_side_info = []
    
    for i in lines: 
        temp = i
        # filter out rows without keywords 'Wall Street Journal' and filter out rows with 'regulation newsletter'
        if ( temp.find("Wall Street Journal") !=-1 and temp.find("financial regulation newsletter") == -1):
            wsj_data = temp 
            date = re.findall(r'\d{4}[,]\s[a-zA-Z]+\s[\d]+', wsj_data)                              
            date_str = date[0]                                                # get the date as string format
            date_str = datetime.strptime(date_str, '%Y, %b %d')
            date_str = datetime.strftime(date_str,'%b %d, %Y')
            date_info.append(date_str)                                        # append the date into a list
            idx_r_p = wsj_data.find(")")                                      # get the index of right parenthesis
            idx_l_p = wsj_data.find("(")                                      # get the index of left parenthesis
            left_side_date = wsj_data[0:idx_l_p]                              # get the lefe part of date in each row
            left_side_info.append(left_side_date)                             # append it into a list 
            right_side_date = wsj_data[idx_r_p+3::]                           # get the right side of date in each row
            right_side_info.append(right_side_date)                           # append it into a list 
            idx_wsj = right_side_date.find("Wall Street Journal")             # get the index of 'Wall Street Journal' of right side of date

            if (idx_wsj == 0):
#               if 'Wall Street Journal' is at the beginning of right side of date, get the headline from the left side of date
                headline = left_side_date
                t_headline = headline.lower()
                raw_headlines.append(t_headline)
                
            else:
#          if 'Wall Street Journal' is not at the beginning of right side of date, get the headline between right parenthesis and Wall Street Journal        
                headline = right_side_date[0:idx_wsj]
                t_headline = headline.lower()     
                raw_headlines.append(t_headline)
            
            raw_data = zip(raw_headlines, date_info)
            
    return raw_data



if __name__ == "__main__":
    print("This web scraper takes about 10 minutes to run")
    print("scraping bloomberg data...")
    bloomberg_raw = get_bloomberg_headlines()
    print("scraping marketwatch data...")
    marketwatch_raw = marketwatch_parser()
    print("scraping WSJ data from txt file...")
    wsj_raw = get_wsj_headlineswsj_raw = get_wsj_headlines()
    print("done scraping all data - stored in list 'all_data_raw' ")

    # All raw data with headlines that don't include keywords filtered out
    all_data_raw = []
    all_data_raw.extend(list(bloomberg_raw) + list(marketwatch_raw) + list(wsj_raw))
    print(all_data_raw)
# Out:
# This web scraper takes about 10 minutes to run
# scraping bloomberg data...
# scraped 20 of 80 pages
# scraped 40 of 80 pages
# scraped 60 of 80 pages
# scraped 80 of 80 pages
# scraping marketwatch data...
# scraping WSJ data from txt file...
# done scraping all data - stored in list 'all_data_raw'
# [(' blockchains warrant skepticism but keep an open mind ', 'Apr 27, 2018 '), (' bitcoin: the past, present and future ', 'Apr 26, 2018 '), (' digital-banking startup revolut is worth $1.7 billion with new funding ', 'Apr 26, 2018 '), (" pantera's morehead says bitcoin 'is a screaming buy' ", 'Apr 26, 2018 '), (' pantera ceo says bitcoin is ‘screaming buy,’ bets on icon ', 'Apr 26, 2018 '), (' crypto world gains even more options: five new fundstrat indexes ', 'Apr 26, 2018 '), (" samsung's winning big from a boom in the boring stuff ", 'Apr 25, 2018 '), (' struggling russians turn to day-trading to pay the bills ', 'Apr 25, 2018 '), (' central bankers can’t agree on cryptocurrencies ', 'Apr 25, 2018 '), (' a software bug in ethereum tokens is helping halt the crypto rally ', 'Apr 25, 2018 '), (' vc firm with rockefeller roots turns to crypto startups ', 'Apr 25, 2018 '), (' what if, hypothetically, yahoo had been hacked? ', 'Apr 25, 2018 '), (" ritholtz's reads: bitcoin's scam, fake video and mosquitoes ", 'Apr 25, 2018 '), (' san francisco will get over scooterpocalypse ', 'Apr 25, 2018 '), (' why schwab’s ceo bets you won’t be trading stocks on amazon ', 'Apr 25, 2018 '), (' winklevoss twins hire nasdaq to keep cheaters off crypto market ', 'Apr 25, 2018 '), (' crypto billionaire sued by sequoia after deal falls apart ', 'Apr 25, 2018 '), (' why some cryptocurrencies are only for the wealthy ', 'Apr 25, 2018 '), (' bitcoin surges while u.s. stocks slump ', 'Apr 24, 2018 '), (" the daily prophet: can't blame 3% bond yield for this stock rout ", 'Apr 24, 2018 '), (' bitcoin is one of the few things surging in a sea of losses ', 'Apr 24, 2018 '), (' index standards and listing standards ', 'Apr 24, 2018 '), (' crypto’s april rally climbs to almost 75% ', 'Apr 24, 2018 '), (' chinese #metoo student activists use blockchain to fight censors ', 'Apr 24, 2018 '), (' five things you need to know to start your day ', 'Apr 23, 2018 '), (' former cftc head says big cryptocurrencies could be classified as securities ', 'Apr 23, 2018 '), (' bitcoin rival accused of trying to artificially boost its price ', 'Apr 23, 2018 '), (' how to avoid a retirement disaster ', 'Apr 23, 2018 '), (' wells fargo pays some more fines ', 'Apr 23, 2018 '), (' iran’s central bank imposes ban on cryptocurrency transactions ', 'Apr 23, 2018 '), (' goldman sachs hires crypto trader justin schmidt to lead digital assets ', 'Apr 23, 2018 '), (' bitcoin breaches $9,000 for the first time in a month ', 'Apr 23, 2018 '), (" ritholtz's reads: seeing red in dyes, bitcoin and demographics ", 'Apr 21, 2018 '), (' how much is bitcoin really worth? ', 'Apr 20, 2018 '), (' kraken defies n.y. attorney general’s cryptocurrency inquiry ', 'Apr 20, 2018 '), (' being short and right can be bad ', 'Apr 20, 2018 '), (' bitcoin is about to have its first back-to-back weekly gain in 2018 ', 'Apr 20, 2018 '), (' four harvard students jump on the crypto hedge-fund bandwagon ', 'Apr 20, 2018 '), (' crypto exchange binance denies it will introduce dollar trading ', 'Apr 20, 2018 '), (' purpose is first question to ask of a cryptocurrency ', 'Apr 19, 2018 '), (' five things you need to know to start your day ', 'Apr 19, 2018 '), (' your evening briefing ', 'Apr 19, 2018 '), (' as bitcoin plunged, these crypto hedge funds kept making money ', 'Apr 19, 2018 '), (' many bitcoin miners are at risk of turning unprofitable ', 'Apr 19, 2018 '), (' brokers may have to put customers first ', 'Apr 19, 2018 '), (" sweden's very own bitcoin. what could possibly go wrong? ", 'Apr 19, 2018 '), (' free trips, tech booms and good oysters ', 'Apr 19, 2018 '), (' what bitcoin is really worth may no longer be such a mystery ', 'Apr 19, 2018 '), (' five things you need to know to start your day ', 'Apr 18, 2018 '), (' bitcoin whale sightings are leaving cryptocurrency traders jumpy ', 'Apr 18, 2018 '), (' bolivar to bitcoin market hits record $1 million per day ', 'Apr 18, 2018 '), (' investors want to b ...

# %%
df = pd.DataFrame(all_data_raw)
df
# Out:
#                                                       0              1
# 0      blockchains warrant skepticism but keep an op...  Apr 27, 2018
# 1                bitcoin: the past, present and future   Apr 26, 2018
# 2      digital-banking startup revolut is worth $1.7...  Apr 26, 2018
# 3      pantera's morehead says bitcoin 'is a screami...  Apr 26, 2018
# 4      pantera ceo says bitcoin is ‘screaming buy,’ ...  Apr 26, 2018
# 5      crypto world gains even more options: five ne...  Apr 26, 2018
# 6      samsung's winning big from a boom in the bori...  Apr 25, 2018
# 7      struggling russians turn to day-trading to pa...  Apr 25, 2018
# 8      central bankers can’t agree on cryptocurrencies   Apr 25, 2018
# 9      a software bug in ethereum tokens is helping ...  Apr 25, 2018
# 10     vc firm with rockefeller roots turns to crypt...  Apr 25, 2018
# 11     what if, hypothetically, yahoo had been hacked?   Apr 25, 2018
# 12     ritholtz's reads: bitcoin's scam, fake video ...  Apr 25, 2018
# 13        san francisco will get over scooterpocalypse   Apr 25, 2018
# 14     why schwab’s ceo bets you won’t be trading st...  Apr 25, 2018
# 15     winklevoss twins hire nasdaq to keep cheaters...  Apr 25, 2018
# 16     crypto billionaire sued by sequoia after deal...  Apr 25, 2018
# 17     why some cryptocurrencies are only for the we...  Apr 25, 2018
# 18              bitcoin surges while u.s. stocks slump   Apr 24, 2018
# 19     the daily prophet: can't blame 3% bond yield ...  Apr 24, 2018
# 20     bitcoin is one of the few things surging in a...  Apr 24, 2018
# 21               index standards and listing standards   Apr 24, 2018
# 22           crypto’s april rally climbs to almost 75%   Apr 24, 2018
# 23     chinese #metoo student activists use blockcha...  Apr 24, 2018
# 24      five things you need to know to start your day   Apr 23, 2018
# 25     former cftc head says big cryptocurrencies co...  Apr 23, 2018
# 26     bitcoin rival accused of trying to artificial...  Apr 23, 2018
# 27                  how to avoid a retirement disaster   Apr 23, 2018
# 28                    wells fargo pays some more fines   Apr 23, 2018
# 29     iran’s central bank imposes ban on cryptocurr...  Apr 23, 2018
# ...                                                 ...            ...
# 1442  test your smarts on the 'star wars' market, ra...   Jan 09, 2017
# 1443  investing in funds & etfs: a monthly analysis ...   Feb 06, 2017
# 1444  investing in funds & etfs: a quarterly analysi...   Oct 09, 2017
# 1445  wall street backs blockchain for savings on de...   Jan 09, 2017
# 1446  this currency has trounced the dow this year, ...   Dec 30, 2016
# 1447  china bitcoin exchanges to impose trading fee;...   Jan 23, 2017
# 1448  how the blockchain could change corporate stru...   Oct 19, 2016
# 1449  coinbase is nearing close on $100 million in f...   Jul 29, 2017
# 1450  j.p. morgan's jamie dimon may hate bitcoin, bu...   Oct 16, 2017
# 1451  n.y. company accused of running bitcoin ponzi ...   Sep 21, 2017
# 1452  where's crypto? let's play geographic roulette...   Aug 25, 2017
# 1453  forget bitcoin. have you heard of imfcoin? imf...   Oct 05, 2017
# 1454  former chief of collapsed bitcoin exchange mt....   Jul 12, 2017
# 1455  bitcoin, paypal used to finance terrorism, ind...   Jan 10, 2017
# 1456  bitcoin, paypal used to finance terrorism, ind...   Jan 09, 2017
# 1457  irs needs to improve monitoring of bitcoin tra...   Nov 08, 2016
# 1458  bitcoin-technology pioneer chris larsen to ste...   Nov 01, 2016
# 1459  what happens when you roll an online lender, a...   Dec 23, 2016
# 1460  no one knows how much to pay in bitcoin cash t...   Aug 25, 2017
# 1461  bitcoin 'fugitives' gather in hong kong to ski...   Sep 20, 2017
# 1462  u.s. targets bitcoin exchange, alleging it fac...   Jul 27, 2017
# 1463  bitcoin bounces around wildly in record-settin...   Sep 30, 2017
# 1464  how a bitcoin clone helped a company raise $12...   May 17, 2017
# 1465  why you won't be buying a coffee with bitcoin ...   Jul 02, 2017
# 1466  goldman sachs explores a new world: trading bi...   Oct 03, 2017
# 1467  goldman sachs explores a new world: trading bi...   Oct 02, 2017
# 1468  bitcoin faces more scrutiny after global hack;...   May 14, 2017
# 1469  cyberattackers' apparent take: just $51,000 so...   May 15, 2017
# 1470  banks turn to virtual world to modernize physi...   Apr 04, 2017
# 1471  should you have bitcoin in an ira? cryptocurre...   Jan 13, 2017
#
# [1472 rows x 2 columns]

# %%
df.to_csv('web scrape.csv')
pd.read_csv('web scrape.csv')
# Out:
#       Unnamed: 0                                                  0  \
# 0              0   blockchains warrant skepticism but keep an op...
# 1              1             bitcoin: the past, present and future
# 2              2   digital-banking startup revolut is worth $1.7...
# 3              3   pantera's morehead says bitcoin 'is a screami...
# 4              4   pantera ceo says bitcoin is ‘screaming buy,’ ...
# 5              5   crypto world gains even more options: five ne...
# 6              6   samsung's winning big from a boom in the bori...
# 7              7   struggling russians turn to day-trading to pa...
# 8              8   central bankers can’t agree on cryptocurrencies
# 9              9   a software bug in ethereum tokens is helping ...
# 10            10   vc firm with rockefeller roots turns to crypt...
# 11            11   what if, hypothetically, yahoo had been hacked?
# 12            12   ritholtz's reads: bitcoin's scam, fake video ...
# 13            13      san francisco will get over scooterpocalypse
# 14            14   why schwab’s ceo bets you won’t be trading st...
# 15            15   winklevoss twins hire nasdaq to keep cheaters...
# 16            16   crypto billionaire sued by sequoia after deal...
# 17            17   why some cryptocurrencies are only for the we...
# 18            18            bitcoin surges while u.s. stocks slump
# 19            19   the daily prophet: can't blame 3% bond yield ...
# 20            20   bitcoin is one of the few things surging in a...
# 21            21             index standards and listing standards
# 22            22         crypto’s april rally climbs to almost 75%
# 23            23   chinese #metoo student activists use blockcha...
# 24            24    five things you need to know to start your day
# 25            25   former cftc head says big cryptocurrencies co...
# 26            26   bitcoin rival accused of trying to artificial...
# 27            27                how to avoid a retirement disaster
# 28            28                  wells fargo pays some more fines
# 29            29   iran’s central bank imposes ban on cryptocurr...
# ...          ...                                                ...
# 1442        1442  test your smarts on the 'star wars' market, ra...
# 1443        1443  investing in funds & etfs: a monthly analysis ...
# 1444        1444  investing in funds & etfs: a quarterly analysi...
# 1445        1445  wall street backs blockchain for savings on de...
# 1446        1446  this currency has trounced the dow this year, ...
# 1447        1447  china bitcoin exchanges to impose trading fee;...
# 1448        1448  how the blockchain could change corporate stru...
# 1449        1449  coinbase is nearing close on $100 million in f...
# 1450        1450  j.p. morgan's jamie dimon may hate bitcoin, bu...
# 1451        1451  n.y. company accused of running bitcoin ponzi ...
# 1452        1452  where's crypto? let's play geographic roulette...
# 1453        1453  forget bitcoin. have you heard of imfcoin? imf...
# 1454        1454  former chief of collapsed bitcoin exchange mt....
# 1455        1455  bitcoin, paypal used to finance terrorism, ind...
# 1456        1456  bitcoin, paypal used to finance terrorism, ind...
# 1457        1457  irs needs to improve monitoring of bitcoin tra...
# 1458        1458  bitcoin-technology pioneer chris larsen to ste...
# 1459        1459  what happens when you roll an online lender, a...
# 1460        1460  no one knows how much to pay in bitcoin cash t...
# 1461        1461  bitcoin 'fugitives' gather in hong kong to ski...
# 1462        1462  u.s. targets bitcoin exchange, alleging it fac...
# 1463        1463  bitcoin bounces around wildly in record-settin...
# 1464        1464  how a bitcoin clone helped a company raise $12...
# 1465        1465  why you won't be buying a coffee with bitcoin ...
# 1466        1466  goldman sachs explores a new world: trading bi...
# 1467        1467  goldman sachs explores a new world: trading bi...
# 1468        1468  bitcoin faces more scrutiny after global hack;...
# 1469        1469  cyberattackers' apparent take: just $51,000 so...
# 1470        1470  banks turn to virtual world to modernize physi...
# 1471        1471  should you have bitcoin in an ira? cryptocurre...
#
#                   1
# 0     Apr 27, 2018
# 1     Apr 26, 2018
# 2     Apr 26, 2018
# 3     Apr 26, 2018
# 4     Apr 26, 2018
# 5     Apr 26, 2018
# 6     Apr 25, 2018
# 7     Apr 25, 2018
# 8     Apr 25, 2018
# 9     Apr 25, 2018
# 10    Apr 25, 2018
# 11    Apr 25, 2018
# 12    Apr 25, 2018
# 13    Apr 25, 2018
# 14    Apr 25, 2018
# 15    Apr 25, 2018
# 16    Apr 25, 2018
# 17    Apr 25, 2018
# 18    Apr 24, 2018
# 19    Apr 24, 2018
# 20    Apr 24, 2018
# 21    Apr 24, 2018
# 22    Apr 24, 2018
# 23    Apr 24, 2018
# 24    Apr 23, 2018
# 25    Apr 23, 2018
# 26    Apr 23, 2018
# 27    Apr 23, 2018
# 28    Apr 23, 2018
# 29    Apr 23, 2018
# ...             ...
# 1442   Jan 09, 2017
# 1443   Feb 06, 2017
# 1444   Oct 09, 2017
# 1445   Jan 09, 2017
# 1446   Dec 30, 2016
# 1447   Jan 23, 2017
# 1448   Oct 19, 2016
# 1449   Jul 29, 2017
# 1450   Oct 16, 2017
# 1451   Sep 21, 2017
# 1452   Aug 25, 2017
# 1453   Oct 05, 2017
# 1454   Jul 12, 2017
# 1455   Jan 10, 2017
# 1456   Jan 09, 2017
# 1457   Nov 08, 2016
# 1458   Nov 01, 2016
# 1459   Dec 23, 2016
# 1460   Aug 25, 2017
# 1461   Sep 20, 2017
# 1462   Jul 27, 2017
# 1463   Sep 30, 2017
# 1464   May 17, 2017
# 1465   Jul 02, 2017
# 1466   Oct 03, 2017
# 1467   Oct 02, 2017
# 1468   May 14, 2017
# 1469   May 15, 2017
# 1470   Apr 04, 2017
# 1471   Jan 13, 2017
#
# [1472 rows x 3 columns]

# %%
# f = open('web scrape', encoding="latin-1")

# %%
# Initialize Sentiment Analyzer 
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
data_with_sentiment_df=pd.DataFrame(data_with_sentiment)
data_with_sentiment_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-facaafb8c85a> in <module>()
# ----> 1 data_with_sentiment_df=pd.DataFrame(data_with_sentiment)
#       2 data_with_sentiment_df
#
# NameError: name 'data_with_sentiment' is not defined

# %%
data_with_sentiment_df.to_csv('data_with_sentiment.csv')

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np
import seaborn as sns
py.init_notebook_mode(connected=True)
# %matplotlib inline

# %%
data1 = pd.read_csv("btc price.csv",encoding='latin-1')
data2 = pd.read_csv("data_with_sentiment.csv",encoding='latin-1')

# %%
data1.info()

# %%
data2.info()

# %%
data1

# %%
len(data2)

# %%
data = pd.merge(data1,data2, on='date', how='inner')

# %%
data.info()

# %%
data

# %%
data['date'] = pd.to_datetime(data['date'].apply(str))
#data = data.sort_values(by='date')
data=data.drop(['Unnamed: 0'], axis=1)

# %%
btc_trace = go.Scatter(x=data['date'], y=data['price(USD)'], name= 'Price')
py.iplot([btc_trace])

# %%
data['price(USD)'].replace(0, np.nan, inplace=True)
data['price(USD)'].fillna(method='ffill', inplace=True)

# %%
btc_trace = go.Scatter(x=data['date'], y=data['price(USD)'], name= 'Price')
py.iplot([btc_trace])

# %%
from sklearn.preprocessing import MinMaxScaler
values = data['price(USD)'].values.reshape(-1,1)
sentiment = data['sentiment'].values.reshape(-1,1)
values = values.astype('float32')
sentiment = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
print(len(train), len(test))
split = train_size

# %%
def create_dataset(dataset, look_back, sentiment):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        np.append(a,sentiment[i])
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back, sentiment[0:train_size])
testX, testY = create_dataset(test, look_back, sentiment[train_size:len(scaled)])

# %%
trainX.shape

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=900, batch_size=500, validation_data=(testX, testY), verbose=0, shuffle=False)

# %%
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
yhat = model.predict(testX)
pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()

# %%
yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
rmse = sqrt(mean_squared_error(testY_inverse, yhat_inverse))
print('Test RMSE: %.3f' % rmse)

# %%
pyplot.plot(yhat_inverse, label='predict')
pyplot.plot(testY_inverse, label='actual', alpha=0.5)
pyplot.legend()
pyplot.show()

# %%
predictDates = data.tail(len(testX)).date

# %%
testY_reshape = testY_inverse.reshape(len(testY_inverse))
yhat_reshape = yhat_inverse.reshape(len(yhat_inverse))

# %%
actual_chart = go.Scatter(x=predictDates, y=testY_reshape, name= 'Actual Price')
predict_chart = go.Scatter(x=predictDates, y=yhat_reshape, name= 'Predict Price')
py.iplot([predict_chart, actual_chart])

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.1, vmin=0)
